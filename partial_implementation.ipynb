# %%
from keras.models import load_model
model = load_model('model.h5')

# %%
import cv2

img = cv2.imread("try.png")

# %%
img.shape
# Out:
# (800, 1520, 3)

# %%
import matplotlib.pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier("/home/satvik/Desktop/Internship/FER-project/haarcascade_frontalface_default.xml")

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
print(gray.shape)
plt.imshow(gray)
# Out:
# (800, 1520)

# %%
faces = face_cascade.detectMultiScale(gray)
for x,y,w,h in faces:
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    facess = face_cascade.detectMultiScale(roi_gray) 
    if len(facess)==0:
        print("Faces not detected")
    else:
        for ex,ey,ew,eh in facess:
            face_roi = roi_gray[ey:ey+eh,ex:ex+ew]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-25-6876ea96cca1> in <module>
# ----> 1 faces = face_cascade.detectMultiScale(gray)
#       2 for x,y,w,h in faces:
#       3     roi_gray = gray[y:y+h, x:x+w]
#       4     roi_color = img[y:y+h, x:x+w]
#       5     cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#
# error: OpenCV(4.5.3) /tmp/pip-req-build-afu9cjzs/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(face_roi,cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Face Emotion Detection

# %%
def emotion_analysis(emotions):
    objects = ('angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt

def plot():
    file = 'capture.jpg'
    true_image = image.load_img(file)
    img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

    x = image.img_to_array(img)
    x = np.expand_dims(x, axis = 0)

    x /= 255

    custom = model.predict(x)
    emotion_analysis(custom[0])


    x = np.array(x, 'float32')
    x = x.reshape([48, 48]);


    plt.imshow(true_image)
    plt.show()

# %%
import cv2
            
def facecrop(image):  
    facedata = '/home/satvik/Desktop/Internship/FER-project/haarcascade_frontalface_default.xml'
    cascade = cv2.CascadeClassifier(facedata)
    img = cv2.imread(image)
    
#     plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    try:

        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)
        if(len(faces)==0):
            print("No faces detected")
        for f in faces:
#             print("Inside for loop")
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]


            cv2.imwrite('capture.jpg', sub_face)
            plot()

    except Exception as e:
        print (e)

# %%
facecrop("surprise.jpg")
# Out:
# OpenCV(4.5.3) /tmp/pip-req-build-afu9cjzs/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
facecrop("happy1.jpg")
# Out:
# OpenCV(4.5.3) /tmp/pip-req-build-afu9cjzs/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
facecrop("neutral.jpg")

# %%
facecrop("sad1.jpg")

# %%
facecrop("angry1.jpg")

# %%
facecrop("angry2.webp")

# %%
facecrop("try.png")

# %%
facecrop("fear.jpg")

# %%
# facecrop("fear2.jpeg")

# %%
# facecrop("veera-neutral.jpeg")

# %%
# facecrop("veera-happy.jpeg")

# %%
import cv2 
import matplotlib.pyplot as plt
img = cv2.imread("try2.jpeg")
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
facecrop("try2.jpeg")
